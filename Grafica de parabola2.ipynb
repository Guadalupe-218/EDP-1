# %% [markdown]
# <a href="https://colab.research.google.com/github/Guadalupe-218/EDP-1/blob/main/Grafica%20de%20parabola2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![ciencias_naturales-flores-naturaleza_y_planeta_tierra_499960581_154305912_1706x960.webp](data:image/webp;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
#definir el rango de x
x=np.linspace(-10,10,400)
y=x**2
plt.figure(figsize=(8,6))
plt.plot(x,y,label='y=x^2',color='green')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0,color='black',linewidth=0.5,ls='--')
plt.axvline(0,color='black',linewidth=0.5,ls='--')
plt.grid(color='gray',linestyle='--',linewidth=0.5)
