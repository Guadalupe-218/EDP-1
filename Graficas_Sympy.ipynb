# %%
from sympy import * # es una biblioteca para matematicas simbolicas

# %% [markdown]
# Es una biblioteca para matematicas simbolicas

# %%
x=symbols('x')

# %% [markdown]
# Declarar una variable

# %%
x**3+300
# Out:
# x**3 + 300

# %% [markdown]
# Se define la funcion que se desea graficar

# %%
c1=plotting.plot(x**3+300)

# %% [markdown]
# plotting.plot es una funcion de sympy para crear graficos. Su funcion principal es representar visualmente datos numericos en forma de graficos.

# %%
cl=plotting.plot(x*x,show=True)
c2=plotting.plot(x**3,show=False)

# %%
c1 #Indica qué es y en qué espacio de memoria está

# %%
c1.append(c2[0]) #Anida las gráficas sin los ejes

# %%
c1

# %%
c1.show()

# %%
c1.extend(c2)

# %%
c1.show()

# %%
c2.show()

# %%
from sympy.plotting import plot

# %%
plot(x**2)

# %%
plot(x**2,(x,-1,1))

# %%
plot(exp(x))
#plot(exp(x),(x,0,2))

# %%
plot(x,x**2,x**3, (x,-2,2))

# %%
plot(x**2,adaptative=False,nb_of_points=10) #Revisar

# %% [markdown]
# ### Curvas parametrizadas

# %%
from sympy import plot_parametric

# %%
s=symbols('s')

# %%
plot_parametric((cos(s)),sin(s))

# %%
plot_parametric((cos(s),sin(s)),(s,s**2),(s,-4,4))

# %%
c2[0].line_color='green'

# %%
c2.show()

# %% [markdown]
# ### Graficas 3D

# %%
from sympy.plotting import plot3d

# %%
x,y=symbols('x y')

# %%
plot3d(x*y)

# %%
plot3d(x*y, (x,-5,5),(y,-5,5))

# %%
plot3d(x*y, -x*y, (x,-5,5),(y,-5,5))

# %%
plot3d((x**2 + y**2, (x,-5,5),(y,-5,5)),(x*y,(x,-3,3),(y,-3,3)))

# %%
from sympy.plotting import plot3d_parametric_line

# %%
plot3d_parametric_line(cos(s),sin(s),s)

# %%
plot3d_parametric_line((cos(s),sin(s),s,(s,-5,5)),(sin(s),s**2,s,(s,-5,5)))

# %%
from sympy.plotting import plot3d_parametric_surface

# %%
u, v =symbols('u v')

# %%
plot3d_parametric_surface(cos(u+v),sin(u-v),u-v)

# %%
plot3d_parametric_surface(cos(v)*cos(u),cos(v)*sin(u),sin(v))

# %% [markdown]
# Funciones implícitas

# %%
from sympy import plot_implicit, symbols, Eq, And

# %%
x, y = symbols(' x y')

# %%
p1 = plot_implicit(Eq(x**2 + y**2, 5))

# %%
p6 = plot_implicit(y > x**2)

# %%
p6 = plot_implicit(And(y > x, y > -x))
